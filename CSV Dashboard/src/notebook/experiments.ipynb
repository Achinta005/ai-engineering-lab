# %%
import pandas as pd

# %%
df = pd.read_csv("../data/sample.csv",encoding="latin1")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
from csv_dashboard.data_loader import load_csv,validate_dataframe

df = load_csv('../data/sample.csv')
validate_dataframe(df)
df.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %% [markdown]
# errors="coerce"
#
# It tells Pandas:
#
# If a value cannot be converted into a valid date, replace it with NaT instead of throwing an error.

# %%
from csv_dashboard.transformations import clean_data,add_calculated_columns,get_summary

df = clean_data(df)

df = add_calculated_columns(df)

df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
summary = get_summary(df)

summary
# Out:
# {'total_rows': 9994,
#  'total_sales': np.float64(2297200.8603),
#  'total_profit': np.float64(286397.0217),
#  'total_quantity': np.int64(37873)}

# %%
df['Region'].unique()
# Out:
# <ArrowStringArray>
# ['South', 'West', 'Central', 'East']
# Length: 4, dtype: str

# %%
df['Category'].head(10)
# Out:
# 0          Furniture
# 1          Furniture
# 2    Office Supplies
# 3          Furniture
# 4    Office Supplies
# 5          Furniture
# 6    Office Supplies
# 7         Technology
# 8    Office Supplies
# 9    Office Supplies
# Name: Category, dtype: str

# %%
from csv_dashboard.filters import filter_by_region,filter_by_category,filter_by_values,filter_by_date

# %%
east_df = filter_by_region(df,'East')
east_df['Region'].unique()
# Out:
# <ArrowStringArray>
# ['East']
# Length: 1, dtype: str

# %%
technology_df = filter_by_category(df,'Technology')
technology_df['Category'].unique()
# Out:
# <ArrowStringArray>
# ['Technology']
# Length: 1, dtype: str

# %%
df['Sub-Category'].unique()
# Out:
# <ArrowStringArray>
# [  'Bookcases',      'Chairs',      'Labels',      'Tables',     'Storage',
#  'Furnishings',         'Art',      'Phones',     'Binders',  'Appliances',
#        'Paper', 'Accessories',   'Envelopes',   'Fasteners',    'Supplies',
#     'Machines',     'Copiers']
# Length: 17, dtype: str

# %%
multiple_cat_df = filter_by_values(df,"Sub-Category",['Bookcases','Chairs'])
multiple_cat_df['Sub-Category'].unique()
# Out:
# <ArrowStringArray>
# ['Bookcases', 'Chairs']
# Length: 2, dtype: str

# %%
from csv_dashboard.charts import sales_by_region

fig = sales_by_region(df)
fig.show()

# %%
from csv_dashboard.charts import profit_by_category

# %%
fig = profit_by_category(df)
fig.show()

# %%
from csv_dashboard.charts import sales_over_time
fig = sales_over_time(df)
fig.show()

# %%
from csv_dashboard.charts import top_products
fig = top_products(df)
fig.show()
